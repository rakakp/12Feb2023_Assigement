# %%
''' Q1 '''
''' The error implies a problem that mostly arises due to the shortage of system resources. On the other hand, the exceptions occur during runtime and compile time. '''

''' Q2 '''
''' The program terminates abruptly when exception is not handled '''

a=5
a/0

''' Q3 '''

try:
    f = open("test5","r")
    f.read()
except Exception as e:
    print("The exception has occurred ",e)
else:
    f.close()
    print("Indise else block")
finally:
    print("Finally is is executed")

''' Q4 '''

''' a '''
try:
    f = open("test5","r")
    f.read()
except Exception as e:
    print("The exception has occurred ",e)
else:
    f.close()
    print("Indise else block")
finally:
    print("Finally is is executed")

''' b '''
try:
    f = open("test5","r")
    f.read()
except Exception as e:
    print("The exception has occurred ",e)
else:
    f.close()
    print("Indise else block")
finally:
    print("Finally is is executed")

''' c '''
class validateAge(Exception):
    def __init__(self,msg):
        self.msg = msg

def checkAge(age):
    if age < 0 :
        raise validateAge("Age entered is negeative")
    if age > 200:
        raise validateAge("Age enetred is more than 200")
    else:
        print("Age is valid")

try:
    age = int(input("Enter the age"))
    checkAge(2000)
except validateAge as e:
    print(e)

''' Q5 '''
''' Built-in exceptions offer information about Python-related problems, and custom exceptions will add information about project-related problems '''

class validateAge(Exception):
    def __init__(self,msg):
        self.msg = msg

def checkAge(age):
    if age < 0 :
        raise validateAge("Age entered is negeative")
    if age > 200:
        raise validateAge("Age enetred is more than 200")
    else:
        print("Age is valid")

try:
    age = int(input("Enter the age"))
    checkAge(2000)
except validateAge as e:
    print(e)

''' Q6 '''
class validateAge(Exception):
    def __init__(self,msg):
        self.msg = msg

def checkAge(age):
    if age < 0 :
        raise validateAge("Age entered is negeative")
    if age > 200:
        raise validateAge("Age enetred is more than 200")
    else:
        print("Age is valid")

try:
    age = int(input("Enter the age"))
    checkAge(2000)
except validateAge as e:
    print(e)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[1], line 8
#       5 ''' The program terminates abruptly when exception is not handled '''
#       7 a=5
# ----> 8 a/0
#      10 ''' Q3 '''
#      12 try:
#
# ZeroDivisionError: division by zero
